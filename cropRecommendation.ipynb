# %% [markdown]
# #Data Interogation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/Crop_recommendation.csv')

# %%
data
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
data.head(6)
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice
# 5  69  37  42    23.058049  83.370118  7.073454  251.055000  rice

# %%
data.tail(5)
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee

# %%
data.shape
# Out:
# (2200, 8)

# %%
data.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
data.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
data.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
data.nunique()
# Out:
# N               137
# P               117
# K                73
# temperature    2200
# humidity       2200
# ph             2200
# rainfall       2200
# label            22
# dtype: int64

# %%
data['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
data['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %%
summary=pd.pivot_table(data,index=['label'],aggfunc='mean')

# %%
summary
# Out:
#                   K       N       P   humidity        ph    rainfall  \
# label
# apple        199.89   20.80  134.22  92.333383  5.929663  112.654779
# banana        50.05  100.23   82.01  80.358123  5.983893  104.626980
# blackgram     19.24   40.02   67.47  65.118426  7.133952   67.884151
# chickpea      79.92   40.09   67.79  16.860439  7.336957   80.058977
# coconut       30.59   21.98   16.93  94.844272  5.976562  175.686646
# coffee        29.94  101.20   28.74  58.869846  6.790308  158.066295
# cotton        19.56  117.77   46.24  79.843474  6.912675   80.398043
# grapes       200.11   23.18  132.53  81.875228  6.025937   69.611829
# jute          39.99   78.40   46.86  79.639864  6.732778  174.792798
# kidneybeans   20.05   20.75   67.54  21.605357  5.749411  105.919778
# lentil        19.41   18.77   68.36  64.804785  6.927932   45.680454
# maize         19.79   77.76   48.44  65.092249  6.245190   84.766988
# ...

# %% [markdown]
# #Data Visualization

# %%
for i in data.columns:
  print(i,end=' ')
# Out:
# N P K temperature humidity ph rainfall label

# %%
for i in data.columns:
  plt.figure(figsize=(5,8))
  sns.boxplot(data[i])
  plt.show()

# %%
summary
# Out:
#                   K       N       P   humidity        ph    rainfall  \
# label
# apple        199.89   20.80  134.22  92.333383  5.929663  112.654779
# banana        50.05  100.23   82.01  80.358123  5.983893  104.626980
# blackgram     19.24   40.02   67.47  65.118426  7.133952   67.884151
# chickpea      79.92   40.09   67.79  16.860439  7.336957   80.058977
# coconut       30.59   21.98   16.93  94.844272  5.976562  175.686646
# coffee        29.94  101.20   28.74  58.869846  6.790308  158.066295
# cotton        19.56  117.77   46.24  79.843474  6.912675   80.398043
# grapes       200.11   23.18  132.53  81.875228  6.025937   69.611829
# jute          39.99   78.40   46.86  79.639864  6.732778  174.792798
# kidneybeans   20.05   20.75   67.54  21.605357  5.749411  105.919778
# lentil        19.41   18.77   68.36  64.804785  6.927932   45.680454
# maize         19.79   77.76   48.44  65.092249  6.245190   84.766988
# ...

# %%
new_summary=summary.reset_index()

# %%
new_summary
# Out:
#           label       K       N       P   humidity        ph    rainfall  \
# 0         apple  199.89   20.80  134.22  92.333383  5.929663  112.654779
# 1        banana   50.05  100.23   82.01  80.358123  5.983893  104.626980
# 2     blackgram   19.24   40.02   67.47  65.118426  7.133952   67.884151
# 3      chickpea   79.92   40.09   67.79  16.860439  7.336957   80.058977
# 4       coconut   30.59   21.98   16.93  94.844272  5.976562  175.686646
# 5        coffee   29.94  101.20   28.74  58.869846  6.790308  158.066295
# 6        cotton   19.56  117.77   46.24  79.843474  6.912675   80.398043
# 7        grapes  200.11   23.18  132.53  81.875228  6.025937   69.611829
# 8          jute   39.99   78.40   46.86  79.639864  6.732778  174.792798
# 9   kidneybeans   20.05   20.75   67.54  21.605357  5.749411  105.919778
# 10       lentil   19.41   18.77   68.36  64.804785  6.927932   45.680454
# 11        maize   19.79   77.76   48.44  65.092249  6.245190   84.766988
# ...

# %%
new_summary.sort_values(by='P',ascending=False)
# Out:
#           label       K       N       P   humidity        ph    rainfall  \
# 0         apple  199.89   20.80  134.22  92.333383  5.929663  112.654779
# 7        grapes  200.11   23.18  132.53  81.875228  6.025937   69.611829
# 1        banana   50.05  100.23   82.01  80.358123  5.983893  104.626980
# 10       lentil   19.41   18.77   68.36  64.804785  6.927932   45.680454
# 3      chickpea   79.92   40.09   67.79  16.860439  7.336957   80.058977
# 18   pigeonpeas   20.29   20.73   67.73  48.061633  5.794175  149.457564
# 9   kidneybeans   20.05   20.75   67.54  21.605357  5.749411  105.919778
# 2     blackgram   19.24   40.02   67.47  65.118426  7.133952   67.884151
# 17       papaya   50.04   49.88   59.05  92.403388  6.741442  142.627839
# 11        maize   19.79   77.76   48.44  65.092249  6.245190   84.766988
# 13    mothbeans   20.23   21.44   48.01  53.160418  6.831174   51.198487
# 20         rice   39.87   79.89   47.58  82.272822  6.425471  236.181114
# ...

# %%
plt.figure(figsize=(12,4))
sns.barplot(y = 'N', x = 'label', data=new_summary, palette = 'hls')
plt.xticks(rotation = 90)
plt.show()
# Out:
# <ipython-input-22-cb70fc820df9>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y = 'N', x = 'label', data=new_summary, palette = 'hls')

# %%
plt.figure(figsize=(12,4))
sns.barplot(y = 'K', x = 'label', data=new_summary, palette = 'hls')
plt.xticks(rotation = 90)
plt.show()
# Out:
# <ipython-input-23-be55feaf7083>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y = 'K', x = 'label', data=new_summary, palette = 'hls')

# %%
plt.figure(figsize=(12,4))
sns.barplot(y = 'P', x = 'label', data=new_summary, palette = 'hls')
plt.xticks(rotation = 90)
plt.show()
# Out:
# <ipython-input-24-e2ef5cb3fa82>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y = 'P', x = 'label', data=new_summary, palette = 'hls')

# %%
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
fig1 = px.bar(new_summary, x='label', y='N')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig1 = px.bar(new_summary, x='label', y='P')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
need_N=summary.sort_values(by='N',ascending=False)
need_N
# Out:
#                   K       N       P   humidity        ph    rainfall  \
# label
# cotton        19.56  117.77   46.24  79.843474  6.912675   80.398043
# coffee        29.94  101.20   28.74  58.869846  6.790308  158.066295
# muskmelon     50.08  100.32   17.72  92.342802  6.358805   24.689952
# banana        50.05  100.23   82.01  80.358123  5.983893  104.626980
# watermelon    50.22   99.42   17.00  85.160375  6.495778   50.786219
# rice          39.87   79.89   47.58  82.272822  6.425471  236.181114
# jute          39.99   78.40   46.86  79.639864  6.732778  174.792798
# maize         19.79   77.76   48.44  65.092249  6.245190   84.766988
# papaya        50.04   49.88   59.05  92.403388  6.741442  142.627839
# chickpea      79.92   40.09   67.79  16.860439  7.336957   80.058977
# blackgram     19.24   40.02   67.47  65.118426  7.133952   67.884151
# grapes       200.11   23.18  132.53  81.875228  6.025937   69.611829
# ...

# %%
need_N=summary.sort_values(by='N',ascending=False)
fig=make_subplots(rows=1,cols=2)
top={
    'y':need_N['N'][0:10].sort_values().index,
    'x':need_N['N'][0:10].sort_values(),
}
bottom={
    'y':need_N['N'][-10:].index,
    'x':need_N['N'][-10:]
}

fig.add_trace(go.Bar(
    top,name='Most Nitrogen Required',marker_color='green',orientation='h',text=top['x']),row=1,col=1
)
fig.add_trace(go.Bar(
    bottom,name='Least Nitrogen Required',marker_color='red',orientation='h',text=bottom['x']),row=1,col=2
)
fig.update_traces(texttemplate='%{text}',textposition='inside')
fig.update_layout(title_text="Nitrogen (N)",
                  plot_bgcolor='white',
                  font_size=7,
                  font_color='black',
                 height=500)

fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(summary, x=summary.index, y=["rainfall", "temperature", "humidity"])
fig.update_layout(title_text="Comparision between Rainfall,Temperature and Humidity",
                  plot_bgcolor='white',
                 height=500)

fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Matrices

# %%
numeric_data=data.select_dtypes(include=[float, int])
correlation_matrix= numeric_data.corr()

# %%
correlation_matrix
# Out:
#                     N         P         K  temperature  humidity        ph  \
# N            1.000000 -0.231460 -0.140512     0.026504  0.190688  0.096683
# P           -0.231460  1.000000  0.736232    -0.127541 -0.118734 -0.138019
# K           -0.140512  0.736232  1.000000    -0.160387  0.190859 -0.169503
# temperature  0.026504 -0.127541 -0.160387     1.000000  0.205320 -0.017795
# humidity     0.190688 -0.118734  0.190859     0.205320  1.000000 -0.008483
# ph           0.096683 -0.138019 -0.169503    -0.017795 -0.008483  1.000000
# rainfall     0.059020 -0.063839 -0.053461    -0.030084  0.094423 -0.109069
#
#              rainfall
# N            0.059020
# P           -0.063839
# K           -0.053461
# temperature -0.030084
# humidity     0.094423
# ph          -0.109069
# rainfall     1.000000

# %%
fig,ax = plt.subplots(1,1,figsize=(12,7))
sns.heatmap(correlation_matrix, annot=True,cmap='Wistia')
ax.set(xlabel='features')
ax.set(ylabel='features')
plt.title('Correlation between different features', fontsize = 12, c='black')
plt.show()

# %% [markdown]
# #Machine learning

# %%
x=data.drop('label',axis=1)
y=data['label']

# %%
pip install scikit-learn==1.3.2

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.33,shuffle = True, random_state = 0)

# %%
import lightgbm as lgb
model = lgb.LGBMClassifier()
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
#
#
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000393 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1327
# [LightGBM] [Info] Number of data points in the train set: 1474, number of used features: 7
# [LightGBM] [Info] Start training from score -3.061629
# [LightGBM] [Info] Start training from score -3.076227
# [LightGBM] [Info] Start training from score -3.121348
# [LightGBM] [Info] Start training from score -3.184861
# [LightGBM] [Info] Start training from score -3.047240
# [LightGBM] [Info] Start training from score -3.076227
# [LightGBM] [Info] Start training from score -3.019069
# ...

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_pred, y_test)
print('LightGBM Model accuracy score: {0:0.6f}'.format(accuracy_score(y_test, y_pred)))
# Out:
# LightGBM Model accuracy score: 0.988981

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        31
#       banana       1.00      1.00      1.00        32
#    blackgram       0.97      0.97      0.97        35
#     chickpea       1.00      1.00      1.00        39
#      coconut       1.00      1.00      1.00        30
#       coffee       1.00      0.97      0.98        32
#       cotton       0.97      1.00      0.98        28
#       grapes       1.00      1.00      1.00        33
#         jute       0.97      0.94      0.95        31
#  kidneybeans       1.00      1.00      1.00        30
#       lentil       1.00      0.96      0.98        26
#        maize       0.93      0.97      0.95        29
#        mango       1.00      1.00      1.00        29
#    mothbeans       0.97      1.00      0.99        39
#     mungbean       1.00      1.00      1.00        31
#    muskmelon       1.00      1.00      1.00        31
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
classifier_rf= RandomForestClassifier(n_estimators= 10, criterion="entropy")
classifier_rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
y_pred= classifier_rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_pred, y_test)
print('Random Forest Model accuracy score: {0:0.6f}'.format(accuracy_score(y_test, y_pred)))
# Out:
# Random Forest Model accuracy score: 0.994490

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        31
#       banana       1.00      1.00      1.00        32
#    blackgram       0.97      1.00      0.99        35
#     chickpea       1.00      1.00      1.00        39
#      coconut       1.00      1.00      1.00        30
#       coffee       1.00      1.00      1.00        32
#       cotton       1.00      1.00      1.00        28
#       grapes       1.00      1.00      1.00        33
#         jute       1.00      0.97      0.98        31
#  kidneybeans       0.97      1.00      0.98        30
#       lentil       1.00      0.96      0.98        26
#        maize       1.00      1.00      1.00        29
#        mango       1.00      1.00      1.00        29
#    mothbeans       0.97      0.95      0.96        39
#     mungbean       1.00      1.00      1.00        31
#    muskmelon       1.00      1.00      1.00        31
# ...

# %%
import pickle

# %%
with open('rf_model.pkl', 'wb') as file:
    pickle.dump(classifier_rf,file)

# %%
def predict(n,p,k,temp,humidity,ph,rainfall):
  with open('rf_model.pkl', 'rb') as file:
    model=pickle.load(file)
  input_data = pd.DataFrame({
      'N': [n],
      'P': [p],
      'K': [k],
      'temperature': [temp],
      'humidity': [humidity],
      'ph': [ph],
      'rainfall': [rainfall]
  })
  prediction = model.predict(input_data)[0]

  return prediction
result = predict(90, 42, 43, 20.87974371, 40.00274423, 6.502985292000001, 100.9355362)
print(f"The predicted crop is: {result}")
# Out:
# The predicted crop is: maize
